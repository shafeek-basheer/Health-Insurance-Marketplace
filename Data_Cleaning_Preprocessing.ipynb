# %% [raw]
# "Benefit Cost Sharing and Financial Analysis"
# 📍 TASK 2: Data Cleaning & Pre-processing
# Handling missing data, duplicates, formatting, derived features, and transformation.
# Data Pre-processing
# ● Perform all necessary cleaning steps such as :
#
#  1. Handling missing values
#  2. Removing duplicates
#  3. Correcting data types
#  4. Creating derived columns
#  5. Filtering or aggregating data

# %% [markdown]
# 1️⃣ Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 2️⃣ Reading the Dataset

# %%
Benifit_cost=pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\project\BenefitsCostSharing.csv")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12712\3598376911.py:1: DtypeWarning: Columns (3,6,9,10,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   Benifit_cost=pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\project\BenefitsCostSharing.csv")

# %% [markdown]
# ➤ Loading the First 5 Columns of Benefit cost sharing Dataset

# %%
Benifit_cost.head(5)
# Out:
#                        BenefitName  BusinessYear CoinsInnTier1 CoinsInnTier2  \
# 0  Routine Dental Services (Adult)          2014           20%           NaN
# 1     Dental Check-Up for Children          2014           20%           NaN
# 2        Basic Dental Care - Child          2014           40%           NaN
# 3              Orthodontia - Child          2014           50%           NaN
# 4        Major Dental Care - Child          2014           50%           NaN
#
#   CoinsOutofNet CopayInnTier1 CopayInnTier2 CopayOutofNet  \
# 0           20%     No Charge           NaN     No Charge
# 1           20%     No Charge           NaN     No Charge
# 2           40%     No Charge           NaN     No Charge
# 3           50%     No Charge           NaN     No Charge
# 4           50%     No Charge           NaN     No Charge
#
#              EHBVarReason Exclusions  ...              LimitUnit MinimumStay  \
# ...

# %% [markdown]
# 3️⃣ Data Pre-processing
# ⏳ 1. Handling missing values

# %%
Benifit_cost.isnull().sum()
# Out:
# BenefitName                  0
# BusinessYear                 0
# CoinsInnTier1          1113847
# CoinsInnTier2          4571587
# CoinsOutofNet          1113847
# CopayInnTier1          1113847
# CopayInnTier2          4571587
# CopayOutofNet          1113849
# EHBVarReason           3020737
# Exclusions             4572247
# Explanation            4075700
# ImportDate                   0
# IsCovered               215980
# IsEHB                  1817362
# IsExclFromInnMOOP       983986
# IsExclFromOonMOOP       982626
# IsStateMandate         4250463
# IsSubjToDedTier1       2465877
# IsSubjToDedTier2       2466054
# IssuerId                     0
# IssuerId2                    0
# LimitQty               4360725
# LimitUnit              4360539
# MinimumStay            5031681
# PlanId                       0
# QuantLimitOnSvc        3264532
# RowNumber                    0
# SourceName                   0
# StandardComponentId          0
# StateCode                    0
# ...

# %% [raw]
# 🔑 Here we found more missing values.
# 🔑 We cant take any action in this data set it more are object any further action its affect data set

# %% [markdown]
# ⏳ 2.Find  duplicates
# 🔑 A . Finding the Total Number of Duplicated Data in the Health-Care DataSet

# %%
Benifit_cost.duplicated().sum()
# Out:
# 86

# %% [raw]
# 🔑 We cant take any action for this its also affect the data set becuse object value are more here in data set
# 🔑 its also repeating

# %% [raw]
# ⏳ 3. Formating Data

# %% [raw]
# 🔑 A. Strip whitespace and convert to title case from Name Column

# %%
Benifit_cost['BenefitName']=Benifit_cost['BenefitName'].str.strip().str.title()

# %%
Benifit_cost.head(2)
# Out:
#                        BenefitName  BusinessYear CoinsInnTier1 CoinsInnTier2  \
# 0  Routine Dental Services (Adult)          2014            20           NaN
# 1     Dental Check-Up For Children          2014            20           NaN
#
#   CoinsOutofNet CopayInnTier1 CopayInnTier2 CopayOutofNet  \
# 0           20%     No Charge           NaN     No Charge
# 1           20%     No Charge           NaN     No Charge
#
#           EHBVarReason Exclusions  ...              LimitUnit MinimumStay  \
# 0            Above EHB        NaN  ...       Dollars per Year         NaN
# 1  Substantially Equal        NaN  ...  Visit(s) per 6 Months         NaN
#
#               PlanId QuantLimitOnSvc RowNumber SourceName StandardComponentId  \
# 0  21989AK0010001-00             Yes        68       HIOS      21989AK0010001
# 1  21989AK0010001-00             Yes       104       HIOS      21989AK0010001
#
#   StateCode StateCode2  VersionNum
# 0        AK         AK           6
# ...

# %% [raw]
# 🔑 B. Strip whitespace and convert to title case Benefit Name  column

# %%
Benifit_cost['BenefitName'] = Benifit_cost['BenefitName'].str.strip().str.rstrip('')

# %%
Benifit_cost.head(2)
# Out:
#                        BenefitName  BusinessYear CoinsInnTier1 CoinsInnTier2  \
# 0  Routine Dental Services (Adult)          2014            20           NaN
# 1     Dental Check-Up For Children          2014            20           NaN
#
#   CoinsOutofNet CopayInnTier1 CopayInnTier2 CopayOutofNet  \
# 0           20%     No Charge           NaN     No Charge
# 1           20%     No Charge           NaN     No Charge
#
#           EHBVarReason Exclusions  ...              LimitUnit MinimumStay  \
# 0            Above EHB        NaN  ...       Dollars per Year         NaN
# 1  Substantially Equal        NaN  ...  Visit(s) per 6 Months         NaN
#
#               PlanId QuantLimitOnSvc RowNumber SourceName StandardComponentId  \
# 0  21989AK0010001-00             Yes        68       HIOS      21989AK0010001
# 1  21989AK0010001-00             Yes       104       HIOS      21989AK0010001
#
#   StateCode StateCode2  VersionNum
# 0        AK         AK           6
# ...

# %% [markdown]
# 🔑 A. Strip extract  and convert to intiger

# %%
Benifit_cost['CoinsInnTier1']=Benifit_cost['CoinsInnTier1'].str.extract('(\\d+)')[0]

# %%
Benifit_cost['CoinsInnTier1']=Benifit_cost['CoinsInnTier1'].fillna(0)

# %%
Benifit_cost['CoinsInnTier1']=Benifit_cost['CoinsInnTier1'].astype(int)

# %%
Benifit_cost.head(3)
# Out:
#                        BenefitName  BusinessYear CoinsInnTier1 CoinsInnTier2  \
# 0  Routine Dental Services (Adult)          2014            20           NaN
# 1     Dental Check-Up For Children          2014            20           NaN
# 2        Basic Dental Care - Child          2014            40           NaN
#
#   CoinsOutofNet CopayInnTier1 CopayInnTier2 CopayOutofNet  \
# 0           20%     No Charge           NaN     No Charge
# 1           20%     No Charge           NaN     No Charge
# 2           40%     No Charge           NaN     No Charge
#
#           EHBVarReason Exclusions  ...              LimitUnit MinimumStay  \
# 0            Above EHB        NaN  ...       Dollars per Year         NaN
# 1  Substantially Equal        NaN  ...  Visit(s) per 6 Months         NaN
# 2  Substantially Equal        NaN  ...                    NaN         NaN
#
#               PlanId QuantLimitOnSvc RowNumber SourceName StandardComponentId  \
# ...

# %%
Benifit_cost['CoinsInnTier2']=Benifit_cost['CoinsInnTier2'].fillna(0)

# %%
Benifit_cost['CoinsInnTier2']=Benifit_cost['CoinsInnTier2'].astype(int)

# %%
Benifit_cost.head(3)
# Out:
#                        BenefitName  BusinessYear CoinsInnTier1 CoinsInnTier2  \
# 0  Routine Dental Services (Adult)          2014            20             0
# 1     Dental Check-Up For Children          2014            20             0
# 2        Basic Dental Care - Child          2014            40             0
#
#   CoinsOutofNet CopayInnTier1 CopayInnTier2 CopayOutofNet  \
# 0           20%     No Charge           NaN     No Charge
# 1           20%     No Charge           NaN     No Charge
# 2           40%     No Charge           NaN     No Charge
#
#           EHBVarReason Exclusions  ...              LimitUnit MinimumStay  \
# 0            Above EHB        NaN  ...       Dollars per Year         NaN
# 1  Substantially Equal        NaN  ...  Visit(s) per 6 Months         NaN
# 2  Substantially Equal        NaN  ...                    NaN         NaN
#
#               PlanId QuantLimitOnSvc RowNumber SourceName StandardComponentId  \
# ...

# %%
Benifit_cost['CoinsOutofNet']=Benifit_cost['CoinsOutofNet'].str.extract('(\\d+)')[0]

# %%
Benifit_cost['CoinsOutofNet']=Benifit_cost['CoinsOutofNet'].astype(int)

# %%
Benifit_cost.head(3)
# Out:
#                        BenefitName  BusinessYear CoinsInnTier1 CoinsInnTier2  \
# 0  Routine Dental Services (Adult)          2014            20             0
# 1     Dental Check-Up For Children          2014            20             0
# 2        Basic Dental Care - Child          2014            40             0
#
#   CoinsOutofNet CopayInnTier1 CopayInnTier2 CopayOutofNet  \
# 0            20     No Charge           NaN     No Charge
# 1            20     No Charge           NaN     No Charge
# 2            40     No Charge           NaN     No Charge
#
#           EHBVarReason Exclusions  ...              LimitUnit MinimumStay  \
# 0            Above EHB        NaN  ...       Dollars per Year         NaN
# 1  Substantially Equal        NaN  ...  Visit(s) per 6 Months         NaN
# 2  Substantially Equal        NaN  ...                    NaN         NaN
#
#               PlanId QuantLimitOnSvc RowNumber SourceName StandardComponentId  \
# ...

# %%
Benifit_cost['CoinsOutofNet'].unique()
# Out:
# array(['20', '40', '50', nan, '0', '30', '100', '80', '60', '45', '65',
#        '10', '15', '35', '70', '25', '90', '5', '55', '75', '85', '49',
#        '8', '28', '46', '19', '37', '33', '3', '95', '2', '21', '58', '1'],
#       dtype=object)

# %%
Benifit_cost['CoinsOutofNet']=Benifit_cost['CoinsOutofNet'].fillna(0)

# %%
Benifit_cost['CoinsOutofNet']=Benifit_cost['CoinsOutofNet'].astype(int)

# %%
Benifit_cost.head(3)
# Out:
#                        BenefitName  BusinessYear CoinsInnTier1 CoinsInnTier2  \
# 0  Routine Dental Services (Adult)          2014            20             0
# 1     Dental Check-Up For Children          2014            20             0
# 2        Basic Dental Care - Child          2014            40             0
#
#   CoinsOutofNet CopayInnTier1 CopayInnTier2 CopayOutofNet  \
# 0            20     No Charge           NaN     No Charge
# 1            20     No Charge           NaN     No Charge
# 2            40     No Charge           NaN     No Charge
#
#           EHBVarReason Exclusions  ...              LimitUnit MinimumStay  \
# 0            Above EHB        NaN  ...       Dollars per Year         NaN
# 1  Substantially Equal        NaN  ...  Visit(s) per 6 Months         NaN
# 2  Substantially Equal        NaN  ...                    NaN         NaN
#
#               PlanId QuantLimitOnSvc RowNumber SourceName StandardComponentId  \
# ...

# %%
Benifit_cost['CopayInnTier1']=Benifit_cost['CopayInnTier1'].str.extract('(\\d+)')[0]

# %%
Benifit_cost['CopayInnTier1'].unique()
# Out:
# array([nan, '0', '45', '15', '10', '25', '30', '35', '50', '60', '17',
#        '8', '20', '150', '100', '200', '40', '300', '55', '395', '75',
#        '5', '70', '80', '65', '500', '350', '1', '750', '125', '1000',
#        '85', '250', '3', '90', '160', '120', '95', '110', '180', '400',
#        '1400', '72', '800', '600', '1500', '9', '6', '4000', '4', '2',
#        '475', '54', '44', '430', '375', '16', '875', '275', '2200', '12',
#        '46', '185', '335', '28', '2000', '1250', '320', '700', '310',
#        '49', '7', '21', '33', '3000', '4500', '2100', '31', '105', '190',
#        '130', '950', '162', '143', '22', '272', '226', '131', '418',
#        '119', '109', '270', '499', '89', '74', '154', '87', '159', '38',
#        '76', '175', '450', '63', '57', '18', '280', '48', '26', '145',
#        '66', '225', '140', '1200', '205', '144', '449', '589', '279',
#        '427', '155', '550', '650', '825', '88', '210', '2500', '900',
# ...

# %%
Benifit_cost['CopayInnTier1']=Benifit_cost['CopayInnTier1'].fillna(0)

# %%
Benifit_cost['CopayInnTier1']=Benifit_cost['CopayInnTier1'].astype(int)

# %%
Benifit_cost['CopayInnTier2']=Benifit_cost['CopayInnTier2'].str.extract('(\\d+)')

# %%
Benifit_cost['CopayInnTier2'].unique()
# Out:
# array([nan, '100', '0', '200', '400', '35', '50', '15', '40', '60', '65',
#        '20', '395', '600', '25', '300', '30', '75', '10', '5', '750',
#        '500', '1', '1000', '1250', '150', '320', '80', '120', '110', '85',
#        '250', '350', '90', '12', '55', '45', '70', '3', '7', '6', '2000',
#        '8', '95', '700', '175', '450', '800', '4', '57', '18', '280',
#        '375', '190', '48', '275', '105', '2', '1300', '1200', '1500',
#        '225', '125', '550', '900', '180', '76', '38', '115', '950', '140',
#        '285', '135', '63', '67', '42', '2500', '525', '425', '1050',
#        '130', '725', '325', '5000', '3500', '4000', '3000', '1550', '240',
#        '1100', '1400', '6600', '6000', '17', '160', '16', '27', '9', '23',
#        '53', '83', '385', '740', '24', '69', '108', '290', '1800', '145',
#        '1600', '2250'], dtype=object)

# %%
Benifit_cost['CopayInnTier2']=Benifit_cost['CopayInnTier2'].fillna(0)

# %%
Benifit_cost['CopayInnTier2'].unique()
# Out:
# array([0, '100', '0', '200', '400', '35', '50', '15', '40', '60', '65',
#        '20', '395', '600', '25', '300', '30', '75', '10', '5', '750',
#        '500', '1', '1000', '1250', '150', '320', '80', '120', '110', '85',
#        '250', '350', '90', '12', '55', '45', '70', '3', '7', '6', '2000',
#        '8', '95', '700', '175', '450', '800', '4', '57', '18', '280',
#        '375', '190', '48', '275', '105', '2', '1300', '1200', '1500',
#        '225', '125', '550', '900', '180', '76', '38', '115', '950', '140',
#        '285', '135', '63', '67', '42', '2500', '525', '425', '1050',
#        '130', '725', '325', '5000', '3500', '4000', '3000', '1550', '240',
#        '1100', '1400', '6600', '6000', '17', '160', '16', '27', '9', '23',
#        '53', '83', '385', '740', '24', '69', '108', '290', '1800', '145',
#        '1600', '2250'], dtype=object)

# %%
Benifit_cost['CopayInnTier2']=Benifit_cost['CopayInnTier2'].astype(int)

# %%
Benifit_cost.head(5)
# Out:
#                        BenefitName  BusinessYear  CoinsInnTier1  \
# 0  Routine Dental Services (Adult)          2014             20
# 1     Dental Check-Up For Children          2014             20
# 2        Basic Dental Care - Child          2014             40
# 3              Orthodontia - Child          2014             50
# 4        Major Dental Care - Child          2014             50
#
#    CoinsInnTier2  CoinsOutofNet  CopayInnTier1  CopayInnTier2 CopayOutofNet  \
# 0              0             20              0              0     No Charge
# 1              0             20              0              0     No Charge
# 2              0             40              0              0     No Charge
# 3              0             50              0              0     No Charge
# 4              0             50              0              0     No Charge
#
#              EHBVarReason Exclusions  ...              LimitUnit MinimumStay  \
# ...

# %%
## In this table maximum values are object type and make a new table

# %%
New_Benifitsharecost=Benifit_cost[['BenefitName','BusinessYear','CoinsInnTier1','CopayInnTier1','PlanId','SourceName','StateCode']]

# %%
New_Benifitsharecost.head(5)
# Out:
#                        BenefitName  BusinessYear  CoinsInnTier1  \
# 0  Routine Dental Services (Adult)          2014             20
# 1     Dental Check-Up For Children          2014             20
# 2        Basic Dental Care - Child          2014             40
# 3              Orthodontia - Child          2014             50
# 4        Major Dental Care - Child          2014             50
#
#    CopayInnTier1             PlanId SourceName StateCode
# 0              0  21989AK0010001-00       HIOS        AK
# 1              0  21989AK0010001-00       HIOS        AK
# 2              0  21989AK0010001-00       HIOS        AK
# 3              0  21989AK0010001-00       HIOS        AK
# 4              0  21989AK0010001-00       HIOS        AK

# %%
📩 Saving the Cleaned Data-Set:

# %%
New_Benifitsharecost.to_csv("cleaned_Benifitcost.csv", index=False)

# %% [markdown]
# ⏳ 5️⃣ Filtering or aggregating data

# %% [raw]
# 🔑 A. Filtering data based on years

# %%
years_plans = New_Benifitsharecost[New_Benifitsharecost['BusinessYear'] == 2016]

# %%
years_plans
# Out:
#                              BenefitName  BusinessYear  CoinsInnTier1  \
# 3244155  Routine Dental Services (Adult)          2016             20
# 3244156     Dental Check-Up For Children          2016             20
# 3244157        Basic Dental Care - Child          2016             30
# 3244158              Orthodontia - Child          2016             50
# 3244159        Major Dental Care - Child          2016             50
# ...                                  ...           ...            ...
# 5048403        Major Dental Care - Child          2016             50
# 5048404        Basic Dental Care - Adult          2016              0
# 5048405              Orthodontia - Adult          2016              0
# 5048406        Major Dental Care - Adult          2016              0
# 5048407                Accidental Dental          2016              0
#
#          CopayInnTier1             PlanId SourceName StateCode
# 3244155              0  21989AK0030001-00       HIOS        AK
# ...

# %% [raw]
# 🔑 B. Aggregating Data
# ▶️ B1. Finding Count of

# %%
New_Benifitsharecost.groupby('BenefitName').count()
# Out:
#                                                  BusinessYear  CoinsInnTier1  \
# BenefitName
# 24/7 Doctor Helpline                                       24             24
# Aba Autism Spectrum Disorders                               4              4
# Aba For Autism Spectrum Disorders                         256            256
# Aba For Autism Spectrum Disprders                           4              4
# Abortion For Which Public Funding Is Prohibited         65704          65704
# ...                                                       ...            ...
# Xrays And Diagnostic Imaging (Hospital)                    48             48
# Clinical - Trials                                        55             55
# Diabetes - Care Management                               55             55
# Mental Health - Other                                    55             55
# Prescription Drugs - Other                               55             55
#
# ...

# %% [markdown]
# ▶️ B2. Average of all CopayInnTier1

# %%
New_Benifitsharecost.groupby('CopayInnTier1').mean(numeric_only = True)
# Out:
#                BusinessYear  CoinsInnTier1
# CopayInnTier1
# 0               2015.128467      10.270051
# 1               2015.114407       2.415254
# 2               2015.083987       0.000000
# 3               2015.020865       0.000000
# 4               2014.883056       0.000000
# ...                     ...            ...
# 4000            2014.542857       0.000000
# 4500            2015.047619       0.000000
# 5000            2015.600000       0.000000
# 6000            2015.000000       0.000000
# 6600            2015.000000       0.000000
#
# [207 rows x 2 columns]

# %%
New_Benifitsharecost[["BusinessYear","BenefitName"]].groupby('BusinessYear').describe()
# Out:
#              BenefitName
#                    count unique                              top   freq
# BusinessYear
# 2014             1164869    479  Routine Dental Services (Adult)  18719
# 2015             2079286    497              Orthodontia - Adult  31269
# 2016             1804253    393              Orthodontia - Adult  27389

# %%
New_Benifitsharecost[["StateCode","BenefitName"]].groupby('StateCode').describe()
# Out:
#           BenefitName
#                 count unique                              top  freq
# StateCode
# AK              41320     84  Routine Dental Services (Adult)   720
# AL              28417    114  Routine Dental Services (Adult)   653
# AR              68064     93              Orthodontia - Adult  1077
# AZ             221612    188        Major Dental Care - Adult  3345
# DE              31370    110              Orthodontia - Adult   602
# FL             364742    183              Orthodontia - Child  5130
# GA             196579    147        Basic Dental Care - Child  2893
# HI               6741     76  Routine Dental Services (Adult)   110
# IA             110221    104     Dental Check-Up For Children  1727
# ID              27313     71     Dental Check-Up For Children   447
# IL             320533    154        Basic Dental Care - Adult  4299
# IN             148531    109        Major Dental Care - Adult  2347
# ...

# %%
New_Benifitsharecost['CoinsInnTier1'].value_counts().head(5)
# Out:
# CoinsInnTier1
# 0     3292267
# 20     699602
# 30     353429
# 50     221323
# 10     208094
# Name: count, dtype: int64

# %%
New_Benifitsharecost.groupby('BusinessYear').sum()
